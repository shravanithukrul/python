# %% [markdown]
# Task 1: Create Class and Object

# %% [markdown]
# Create a class

# %%
class Train:

   train_name = "Rajdhani Express"
   source_station = "Mumbai"
   destination_station = "Delhi"

# %% [markdown]
# Create an Object for Class

# %%
train1 = Train()

# %% [markdown]
# Display Details

# %%
print("Train Name :", train1.train_name)
print("Source Station :", train1.source_station)
print("Destination Station :", train1.destination_station)
# Out:
# Train Name : Rajdhani Express
# Source Station : Mumbai
# Destination Station : Delhi

# %% [markdown]
# Task 2: Add Attributes and Methods

# %% [markdown]
# Add Method and Attributes in Class

# %%
class Passenger:

    passenger_name = "Rahul Sharma"
    seat_number = "B1-21"

    def display_ticket(self):

        print("Passenger Name :", self.passenger_name)
        print("Seat Number :", self.seat_number)
        print("Reservation Confirmed")

# %% [markdown]
# Create Object for Class

# %%
passenger1 = Passenger()

# %% [markdown]
# Call Class Method

# %%
passenger1.display_ticket()
# Out:
# Passenger Name : Rahul Sharma
# Seat Number : B1-21
# Reservation Confirmed

# %% [markdown]
# Task 3: Handle Multiple Reservation Using Object

# %% [markdown]
# Create Reservation class

# %%
class Reservation:


   train_name = "Shatabdi Express"

   def reservation_status(self):
     print("Reservation Confirmed")

# %% [markdown]
# Create multiple reservation objects

# %%
ticket1 = Reservation()
ticket2 = Reservation()

# %% [markdown]
# Access object details

# %%
print(ticket1.train_name)
ticket1.reservation_status()

print(ticket2.train_name)
ticket2.reservation_status()
# Out:
# Shatabdi Express
# Reservation Confirmed
# Shatabdi Express
# Reservation Confirmed

# %% [markdown]
# Task 4: Build Final Reservation System

# %% [markdown]
# Create Railway Reservation class

# %%
class RailwayReservation:

   train_name = "Rajdhani Express"
   passenger_name = "Priya Singh"
   seat_number = "A1-21"
   ticket_price = 2450

   def display_ticket(self):

       print("===================================")
       print(" Railway Reservation Ticket ")
       print("===================================")
       print("Passenger Name :", self.passenger_name)
       print("Train Name :", self.train_name)
       print("Seat Number :", self.seat_number)
       print("Ticket Price :", self.ticket_price)
       print("Reservation Status : Confirmed")

# %% [markdown]
# Create Object

# %%
ticket = RailwayReservation()

# %% [markdown]
# Call Method

# %%
ticket.display_ticket()
# Out:
# ...
#  Railway Reservation Ticket
# ...
# Passenger Name : Priya Singh
# Train Name : Rajdhani Express
# Seat Number : A1-21
# Ticket Price : 2450
# Reservation Status : Confirmed
